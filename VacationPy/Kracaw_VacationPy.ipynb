# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pprint import pprint
import json

# Import API key
from geo_key import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     noyabrsk  63.1994   75.4507      0.39        94         100
# 1        1  yellowknife  62.4560 -114.3525      2.29        64          75
# 2        2     tazovsky  67.4667   78.7000     -2.18        96         100
# 3        3      gudauta  43.1055   40.6207     11.69        83          46
# 4        4       viedma -40.8135  -62.9967     22.02        33         100
#
#    Wind Speed Country        Date
# 0        3.79      RU  1682097563
# 1        5.66      CA  1682097563
# 2        4.77      RU  1682097564
# 3        0.99      GE  1682097564
# 4        9.30      AR  1682097564

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color = "City",
    alpha = 0.5    
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_weather_df = city_data_df.loc[city_data_df["Max Temp"] > 21]
ideal_weather_df = ideal_weather_df.loc[ideal_weather_df['Max Temp'] < 27]

ideal_weather_df = ideal_weather_df.loc[ideal_weather_df['Wind Speed'] < 5]
ideal_weather_df = ideal_weather_df.loc[ideal_weather_df['Cloudiness'] < 30]
ideal_weather_df = ideal_weather_df.loc[ideal_weather_df['Humidity'] < 90]

# Drop any rows with null values
ideal_weather_df.dropna()

# Display sample data
ideal_weather_df
# Out:
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 15        15             sao vicente -23.9631  -46.3919     26.10        66
# 27        27      madinat ash shamal  26.1293   51.2009     26.07        48
# 28        28                 tsiombe -25.3000   45.4833     22.55        82
# 30        30           ilha solteira -20.4328  -51.3425     24.30        47
# 52        52            antonio enes -16.2325   39.9086     25.59        80
# 105      105          howard springs -12.4970  131.0470     24.95        89
# 125      125                  at taj  24.2049   23.2857     26.93        11
# 127      127  san ignacio rio muerto  27.4167 -110.2333     26.29         9
# 186      186            san patricio  28.0170  -97.5169     25.97        53
# 191      191             sidrolandia -20.9319  -54.9614     23.59        54
# 207      207                beroroha -21.6667   45.1667     25.77        61
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df.copy()
hotel_df = hotel_df.drop(columns=['City_ID', 'Max Temp', 'Cloudiness', 'Wind Speed', 'Date'])

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
new_cols = ['City', 'Country', 'Lat', 'Lng', 'Humidity']
hotel_df = hotel_df[new_cols]
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df
# Out:
#                        City Country      Lat       Lng  Humidity Hotel Name
# 15              sao vicente      BR -23.9631  -46.3919        66
# 27       madinat ash shamal      QA  26.1293   51.2009        48
# 28                  tsiombe      MG -25.3000   45.4833        82
# 30            ilha solteira      BR -20.4328  -51.3425        47
# 52             antonio enes      MZ -16.2325   39.9086        80
# 105          howard springs      AU -12.4970  131.0470        89
# 125                  at taj      LY  24.2049   23.2857        11
# 127  san ignacio rio muerto      MX  27.4167 -110.2333         9
# 186            san patricio      US  28.0170  -97.5169        53
# 191             sidrolandia      BR -20.9319  -54.9614        54
# 207                beroroha      MG -21.6667   45.1667        61
# 208         figuig (centre)      MA  32.1089   -1.2286        11
# 213                cidreira      BR -30.1811  -50.2056        59
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
print(geoapify_key)
# Out:
# f4ef75790deb43d0898b982ee9d43643

# %%
base_url = "https://api.geoapify.com/v2/places"
radius = 10000
latitude = 20.9219
longitude = -156.3051
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"
params = {
    
    "filter":filters,
    "bias":bias,
    "apiKey":geoapify_key    
}
name_address = requests.get(base_url, params=params)
name_address = name_address.json()
pprint(name_address["features"][0]["properties"]["name"])
# Out:
# "Inn At Mama's Fish House"

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey":geoapify_key    
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = ideal_weather_df.loc[index, 'Lat']
    longitude = ideal_weather_df.loc[index, 'Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# sao vicente - nearest hotel: Pousada Vitória
# madinat ash shamal - nearest hotel: No hotel found
# tsiombe - nearest hotel: No hotel found
# ilha solteira - nearest hotel: Hotel Urubupungá
# antonio enes - nearest hotel: Hotel Quirimbas
# howard springs - nearest hotel: No hotel found
# at taj - nearest hotel: No hotel found
# san ignacio rio muerto - nearest hotel: No hotel found
# san patricio - nearest hotel: No hotel found
# sidrolandia - nearest hotel: No hotel found
# beroroha - nearest hotel: No hotel found
# figuig (centre) - nearest hotel: No hotel found
# cidreira - nearest hotel: Hotel Castelo
# al jawf - nearest hotel: No hotel found
# jakhal - nearest hotel: No hotel found
# cam ranh - nearest hotel: Khách sạn Thái Bình
# tolanaro - nearest hotel: Hôtel Mahavokey
# saint-pierre - nearest hotel: Tropic Hotel
# mount isa - nearest hotel: Ibis Styles
# guerrero negro - nearest hotel: Plaza sal paraiso
# tazacorte - nearest hotel: App Leyma
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    color = "City",
    alpha = 0.5,
    hover_cols = ["Country", "Hotel Name"]    
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Country,Hotel Name)

# %%
# Map plot without "No Hotel Found"
cleaned_hotel_df = hotel_df.loc[hotel_df['Hotel Name'] != "No hotel found"]
map_plot_3 = cleaned_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    color = "City",
    alpha = 0.5,
    hover_cols = ["Country", "Hotel Name"]    
)
map_plot_3
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Country,Hotel Name)
